# %%
import pandas as pd
import os
import numpy as np

# %%
os.chdir("D:\ML\merge")

# %%
os.listdir()
# Out:
# ['finalflight2016.csv',
#  'finalflight2017.csv',
#  'merge16.csv',
#  'merge2017.csv',
#  'newmerge16.csv',
#  'newmerge17.csv',
#  'weather16.csv',
#  'weather17.csv']

# %%
f16=pd.read_csv("finalflight2016.csv")
f17=pd.read_csv("finalflight2017.csv")
m16=pd.read_csv("newmerge16.csv")
m17=pd.read_csv("newmerge17.csv")
w16=pd.read_csv("weather16.csv")
w17=pd.read_csv("weather17.csv")

# %%
f16["ArrFlightDate"]=f16["FlightDate"]
f16.ArrFlightDate=pd.to_datetime(f16.ArrFlightDate)
f16.FlightDate=pd.to_datetime(f16.FlightDate)
f16["ArrAbsTime"]=f16["CRSArrTime"]
f16
# Out:
#         Unnamed: 0 FlightDate  Quarter  Year  Month  DayofMonth  DepTime  \
# 0               17 2016-09-01        3  2016      9           1    827.0
# 1               18 2016-09-02        3  2016      9           2    828.0
# 2               19 2016-09-04        3  2016      9           4    823.0
# 3               20 2016-09-05        3  2016      9           5    827.0
# 4               21 2016-09-06        3  2016      9           6    826.0
# 5               22 2016-09-07        3  2016      9           7    823.0
# 6               23 2016-09-08        3  2016      9           8    826.0
# 7               24 2016-09-09        3  2016      9           9    829.0
# 8               25 2016-09-10        3  2016      9          10    825.0
# 9               26 2016-09-11        3  2016      9          11    822.0
# 10              27 2016-09-12        3  2016      9          12    827.0
# 11              28 2016-09-13        3  2016      9          13    826.0
# ...

# %%
for index, row in f16.iterrows():
    lastdigits=row["ArrAbsTime"]%100
    absolutetime=row["ArrAbsTime"]-lastdigits
    f16.at[index,"ArrAbsTime"]=absolutetime
    if(row["CRSDepTime"]>row["CRSArrTime"]):
        f16.at[index,"ArrFlightDate"]= row["FlightDate"]+pd.DateOffset(days=1)
f16
# Out:
#         Unnamed: 0 FlightDate  Quarter  Year  Month  DayofMonth  DepTime  \
# 0               17 2016-09-01        3  2016      9           1    827.0
# 1               18 2016-09-02        3  2016      9           2    828.0
# 2               19 2016-09-04        3  2016      9           4    823.0
# 3               20 2016-09-05        3  2016      9           5    827.0
# 4               21 2016-09-06        3  2016      9           6    826.0
# 5               22 2016-09-07        3  2016      9           7    823.0
# 6               23 2016-09-08        3  2016      9           8    826.0
# 7               24 2016-09-09        3  2016      9           9    829.0
# 8               25 2016-09-10        3  2016      9          10    825.0
# 9               26 2016-09-11        3  2016      9          11    822.0
# 10              27 2016-09-12        3  2016      9          12    827.0
# 11              28 2016-09-13        3  2016      9          13    826.0
# ...

# %%
f16=f16.dropna()

# %%
f16['ArrAbsTime'] = f16['ArrAbsTime'].astype(np.int64)
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
f16["DepAbsTime"]=f16["CRSDepTime"]
for index, row in f16.iterrows():
    lastdigits=row["DepAbsTime"]%100
    absolutetime=row["DepAbsTime"]-lastdigits
    f16.at[index,"DepAbsTime"]=absolutetime
f16
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#         Unnamed: 0 FlightDate  Quarter  Year  Month  DayofMonth  DepTime  \
# 0               17 2016-09-01        3  2016      9           1    827.0
# 1               18 2016-09-02        3  2016      9           2    828.0
# 2               19 2016-09-04        3  2016      9           4    823.0
# 3               20 2016-09-05        3  2016      9           5    827.0
# 4               21 2016-09-06        3  2016      9           6    826.0
# 5               22 2016-09-07        3  2016      9           7    823.0
# 6               23 2016-09-08        3  2016      9           8    826.0
# ...

# %%
f16['DepAbsTime'] = f16['DepAbsTime'].astype(np.int64)
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
f16.dtypes
# Out:
# Unnamed: 0                  int64
# FlightDate         datetime64[ns]
# Quarter                     int64
# Year                        int64
# Month                       int64
# DayofMonth                  int64
# DepTime                   float64
# DepDel15                  float64
# CRSDepTime                  int64
# DepDelayMinutes           float64
# OriginAirportID             int64
# DestAirportID               int64
# ArrTime                   float64
# CRSArrTime                  int64
# ArrDel15                  float64
# ArrDelayMinutes           float64
# Origin                     object
# Dest                       object
# ArrFlightDate      datetime64[ns]
# ArrAbsTime                  int64
# DepAbsTime                  int64
# dtype: object

# %%
w16.date=pd.to_datetime(w16.date)
w16.dtypes
# Out:
# Unnamed: 0                int64
# windspeedKmph             int64
# weatherCode               int64
# precipMM                float64
# WindGustKmph              int64
# pressure                  int64
# cloudcover                int64
# winddirDegree             int64
# humidity                  int64
# cloudcover.1              int64
# DewPointF                 int64
# tempF                     int64
# time                      int64
# WindChillF                int64
# date             datetime64[ns]
# airport                  object
# dtype: object

# %%
f17["ArrFlightDate"]=f17["FlightDate"]
f17.ArrFlightDate=pd.to_datetime(f17.ArrFlightDate)
f17.FlightDate=pd.to_datetime(f17.FlightDate)
f17["ArrAbsTime"]=f17["CRSArrTime"]
f17
# Out:
#         Unnamed: 0 FlightDate  Quarter  Year  Month  DayofMonth  DepTime  \
# 0               25 2017-09-25        3  2017      9          25   1340.0
# 1               34 2017-09-25        3  2017      9          25    856.0
# 2               35 2017-09-25        3  2017      9          25   2045.0
# 3               38 2017-09-25        3  2017      9          25   1939.0
# 4               39 2017-09-25        3  2017      9          25   1655.0
# 5               41 2017-09-25        3  2017      9          25   2129.0
# 6               42 2017-09-25        3  2017      9          25   1636.0
# 7               68 2017-09-25        3  2017      9          25    806.0
# 8               72 2017-09-25        3  2017      9          25   2014.0
# 9               91 2017-09-25        3  2017      9          25   2102.0
# 10             102 2017-09-25        3  2017      9          25     24.0
# 11             126 2017-09-25        3  2017      9          25   2321.0
# ...

# %%
for index, row in f17.iterrows():
    lastdigits=row["ArrAbsTime"]%100
    absolutetime=row["ArrAbsTime"]-lastdigits
    f17.at[index,"ArrAbsTime"]=absolutetime
    if(row["CRSDepTime"]>row["CRSArrTime"]):
        f17.at[index,"ArrFlightDate"]= row["FlightDate"]+pd.DateOffset(days=1)
f17
# Out:
#         Unnamed: 0 FlightDate  Quarter  Year  Month  DayofMonth  DepTime  \
# 0               25 2017-09-25        3  2017      9          25   1340.0
# 1               34 2017-09-25        3  2017      9          25    856.0
# 2               35 2017-09-25        3  2017      9          25   2045.0
# 3               38 2017-09-25        3  2017      9          25   1939.0
# 4               39 2017-09-25        3  2017      9          25   1655.0
# 5               41 2017-09-25        3  2017      9          25   2129.0
# 6               42 2017-09-25        3  2017      9          25   1636.0
# 7               68 2017-09-25        3  2017      9          25    806.0
# 8               72 2017-09-25        3  2017      9          25   2014.0
# 9               91 2017-09-25        3  2017      9          25   2102.0
# 10             102 2017-09-25        3  2017      9          25     24.0
# 11             126 2017-09-25        3  2017      9          25   2321.0
# ...

# %%
f17=f17.dropna()
f17['ArrAbsTime'] = f17['ArrAbsTime'].astype(np.int64)

f17["DepAbsTime"]=f17["CRSDepTime"]
for index, row in f17.iterrows():
    lastdigits=row["DepAbsTime"]%100
    absolutetime=row["DepAbsTime"]-lastdigits
    f17.at[index,"DepAbsTime"]=absolutetime
f17
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#         Unnamed: 0 FlightDate  Quarter  Year  Month  DayofMonth  DepTime  \
# 0               25 2017-09-25        3  2017      9          25   1340.0
# 1               34 2017-09-25        3  2017      9          25    856.0
# ...

# %%
f17['DepAbsTime'] = f17['DepAbsTime'].astype(np.int64)
w17.date=pd.to_datetime(w17.date)
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
f16.shape
# Out:
# (936961, 21)

# %%
f16.dtypes
# Out:
# Unnamed: 0                  int64
# FlightDate         datetime64[ns]
# Quarter                     int64
# Year                        int64
# Month                       int64
# DayofMonth                  int64
# DepTime                   float64
# DepDel15                  float64
# CRSDepTime                  int64
# DepDelayMinutes           float64
# OriginAirportID             int64
# DestAirportID               int64
# ArrTime                   float64
# CRSArrTime                  int64
# ArrDel15                  float64
# ArrDelayMinutes           float64
# Origin                     object
# Dest                       object
# ArrFlightDate      datetime64[ns]
# ArrAbsTime                  int64
# DepAbsTime                  int64
# dtype: object

# %%
f17.shape
# Out:
# (914475, 21)

# %%
f17.dtypes
# Out:
# Unnamed: 0                  int64
# FlightDate         datetime64[ns]
# Quarter                     int64
# Year                        int64
# Month                       int64
# DayofMonth                  int64
# DepTime                   float64
# DepDel15                  float64
# CRSDepTime                  int64
# DepDelayMinutes           float64
# OriginAirportID             int64
# DestAirportID               int64
# ArrTime                   float64
# CRSArrTime                  int64
# ArrDel15                  float64
# ArrDelayMinutes           float64
# Origin                     object
# Dest                       object
# ArrFlightDate      datetime64[ns]
# ArrAbsTime                  int64
# DepAbsTime                  int64
# dtype: object

# %%
f=pd.concat([f16,f17],axis = 0)

# %%
f.shape
# Out:
# (1851436, 21)

# %%
f.dtypes
# Out:
# Unnamed: 0                  int64
# FlightDate         datetime64[ns]
# Quarter                     int64
# Year                        int64
# Month                       int64
# DayofMonth                  int64
# DepTime                   float64
# DepDel15                  float64
# CRSDepTime                  int64
# DepDelayMinutes           float64
# OriginAirportID             int64
# DestAirportID               int64
# ArrTime                   float64
# CRSArrTime                  int64
# ArrDel15                  float64
# ArrDelayMinutes           float64
# Origin                     object
# Dest                       object
# ArrFlightDate      datetime64[ns]
# ArrAbsTime                  int64
# DepAbsTime                  int64
# dtype: object

# %%
for index,row in f.iterrows():
    if(row["CRSArrTime"]==2400):
        f.at[index,"CRSArrTime"]=0
        f.at[index,"ArrAbsTime"]=0

# %%
count = 0
for index,row in f.iterrows():
    if(row["CRSArrTime"]==0):
        count = count + 1
print(count)
# Out:
# 30

# %%
w16.shape
# Out:
# (131760, 16)

# %%
w17.shape
# Out:
# (131400, 16)

# %%
w = pd.concat([w16,w17],axis = 0)

# %%
mergeA=f.merge(w,left_on=["FlightDate","DepAbsTime","Origin"],right_on=["date","time","airport"])
mergeA.shape
# Out:
# (1851436, 37)

# %%
mergeB=mergeA.merge(w,left_on=["ArrFlightDate","ArrAbsTime","Dest"],right_on=["date","time","airport"])
mergeB
# Out:
#          Unnamed: 0_x FlightDate  Quarter  Year  Month  DayofMonth  DepTime  \
# 0                  17 2016-09-01        3  2016      9           1    827.0
# 1              105626 2016-09-01        3  2016      9           1    824.0
# 2              152853 2016-09-01        3  2016      9           1    814.0
# 3              228670 2016-09-01        3  2016      9           1   1011.0
# 4              236392 2016-09-01        3  2016      9           1   1153.0
# 5              352684 2016-09-01        3  2016      9           1    941.0
# 6              229088 2016-09-01        3  2016      9           1    938.0
# 7               10154 2016-09-01        3  2016      9           1    848.0
# 8               13868 2016-09-01        3  2016      9           1   1005.0
# 9               55711 2016-09-01        3  2016      9           1   1001.0
# 10             451947 2016-09-01        3  2016      9           1    914.0
# ...

# %%
mergeB.shape
# Out:
# (1851334, 53)

# %%
mergeB.to_csv("bestmerge.csv")
